# %%
list1=[ ]
ch=0
while(1):
    print(".................................................")
    print("MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:")
    print(".................................................")
    print("1. Create a new list.")
    print("2. Inserting a new element to the list.")
    print("3. Removing an existing element from the list.")
    print("4. Appending a new element to the list.")
    print("5. Length of the list.")
    print("6. Popping an element from the list.")
    print("7. Clear")
    print("8. Exit.")
    ch=int(input("Enter your choice: "))
    if ch==1:
        n=int(input("Enter the new element of the list: "))
        list1.append(n)
        print("The new element is inserted to the list.")
        print("After insertion the new list is: ", list1)
    elif ch==2:
        index=int(input("Enter the index at which the element is to be inserted: "))
        n=int(input("Enter the new element to be inserted to the list: "))
        list1.insert(index,n)
        print("The new element is inserted at the specified index.")
        print("After insertion the new list is: ", list1)
    elif ch==3:
        n=int(input("Enter an element to be removed from the list: "))
        if n in list1:
            list1.remove(n)
            print("The specified element is removed from the list.")
            print("After removing the new list is: ", list1)
        else:
            print("The element is not found!!!")
    elif ch==4:
        n=int(input("Enter the element to be appended to the list: "))
        list1.append(n)
        print("The element is appended to the list.")
        print("After insertion the new list is: ", list1)
    elif ch==5:
        print("The length of the list is: ",len(list1))
    elif ch==6:
        index=int(input("Enter the index of the element to be popped from the list: "))
        if index in list1:
            list1.pop(index)
            print("The element of the specified index is popped from the list.")
            print("After popping the new list is: ", list1)
        else:
            print("The element is not found!!!")
    elif ch==7:
        l=list1.clear()
        print("The list is cleared. ",l)
    elif ch==8:
        break
    else:
        print("Invalid choice!!! Try again.")
# Out:
# .................................................
# MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:
# .................................................
# 1. Create a new list.
# 2. Inserting a new element to the list.
# 3. Removing an existing element from the list.
# 4. Appending a new element to the list.
# 5. Length of the list.
# 6. Popping an element from the list.
# 7. Clear
# 8. Exit.
# Enter your choice: 1
# Enter the new element of the list: 34
# The new element is inserted to the list.
# After insertion the new list is:  [34]
# .................................................
# MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:
# .................................................
# 1. Create a new list.
# 2. Inserting a new element to the list.
# 3. Removing an existing element from the list.
# 4. Appending a new element to the list.
# 5. Length of the list.
# 6. Popping an element from the list.
# 7. Clear
# 8. Exit.
# Enter your choice: 1
# Enter the new element of the list: 57
# The new element is inserted to the list.
# After insertion the new list is:  [34, 57]
# .................................................
# MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:
# .................................................
# 1. Create a new list.
# 2. Inserting a new element to the list.
# 3. Removing an existing element from the list.
# 4. Appending a new element to the list.
# 5. Length of the list.
# 6. Popping an element from the list.
# 7. Clear
# 8. Exit.
# Enter your choice: 1
# Enter the new element of the list: 8
# The new element is inserted to the list.
# After insertion the new list is:  [34, 57, 8]
# .................................................
# MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:
# .................................................
# 1. Create a new list.
# 2. Inserting a new element to the list.
# 3. Removing an existing element from the list.
# 4. Appending a new element to the list.
# 5. Length of the list.
# 6. Popping an element from the list.
# 7. Clear
# 8. Exit.
# Enter your choice: 1
# Enter the new element of the list: 73
# The new element is inserted to the list.
# After insertion the new list is:  [34, 57, 8, 73]
# .................................................
# MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:
# .................................................
# 1. Create a new list.
# 2. Inserting a new element to the list.
# 3. Removing an existing element from the list.
# 4. Appending a new element to the list.
# 5. Length of the list.
# 6. Popping an element from the list.
# 7. Clear
# 8. Exit.
# Enter your choice: 2
# Enter the index at which the element is to be inserted: 4
# Enter the new element to be inserted to the list: 29
# The new element is inserted at the specified index.
# After insertion the new list is:  [34, 57, 8, 73, 29]
# .................................................
# MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:
# .................................................
# 1. Create a new list.
# 2. Inserting a new element to the list.
# 3. Removing an existing element from the list.
# 4. Appending a new element to the list.
# 5. Length of the list.
# 6. Popping an element from the list.
# 7. Clear
# 8. Exit.
# Enter your choice: 2
# Enter the index at which the element is to be inserted: 1
# Enter the new element to be inserted to the list: 90
# The new element is inserted at the specified index.
# After insertion the new list is:  [34, 90, 57, 8, 73, 29]
# .................................................
# MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:
# .................................................
# 1. Create a new list.
# 2. Inserting a new element to the list.
# 3. Removing an existing element from the list.
# 4. Appending a new element to the list.
# 5. Length of the list.
# 6. Popping an element from the list.
# 7. Clear
# 8. Exit.
# Enter your choice: 3
# Enter an element to be removed from the list: 8
# The specified element is removed from the list.
# After removing the new list is:  [34, 90, 57, 73, 29]
# .................................................
# MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:
# .................................................
# 1. Create a new list.
# 2. Inserting a new element to the list.
# 3. Removing an existing element from the list.
# 4. Appending a new element to the list.
# 5. Length of the list.
# 6. Popping an element from the list.
# 7. Clear
# 8. Exit.
# Enter your choice: 4
# Enter the element to be appended to the list: 123
# The element is appended to the list.
# After insertion the new list is:  [34, 90, 57, 73, 29, 123]
# .................................................
# MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:
# .................................................
# 1. Create a new list.
# 2. Inserting a new element to the list.
# 3. Removing an existing element from the list.
# 4. Appending a new element to the list.
# 5. Length of the list.
# 6. Popping an element from the list.
# 7. Clear
# 8. Exit.
# Enter your choice: 5
# The length of the list is:  6
# .................................................
# MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:
# .................................................
# 1. Create a new list.
# 2. Inserting a new element to the list.
# 3. Removing an existing element from the list.
# 4. Appending a new element to the list.
# 5. Length of the list.
# 6. Popping an element from the list.
# 7. Clear
# 8. Exit.
# Enter your choice: 6
# Enter the index of the element to be popped from the list: 4
# The element is not found!!!
# .................................................
# MENU DRIVEN PROGRAAM FOR VARIOUS LIST OPERATIONS:
# .................................................
# 1. Create a new list.
# 2. Inserting a new element to the list.
# 3. Removing an existing element from the list.
# 4. Appending a new element to the list.
# 5. Length of the list.
# 6. Popping an element from the list.
# 7. Clear
# 8. Exit.
